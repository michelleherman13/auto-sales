# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# %%
df = pd.read_csv('final_data.csv')
df
# Out:
#     MonthYear  Year      Sales  Price Per Gallon  Unemployment_Rate  \
# 0    Jan-2005  2005  1052224.0             1.831                5.3
# 1    Feb-2005  2005  1244753.0             1.910                5.4
# 2    Mar-2005  2005  1564938.0             2.079                5.2
# 3    Apr-2005  2005  1493837.0             2.243                5.2
# 4    May-2005  2005  1488171.0             2.161                5.1
# ..        ...   ...        ...               ...                ...
# 193  Feb-2021  2021  1256529.0             2.501                6.2
# 194  Mar-2021  2021  1536038.0             2.810                6.0
# 195  Apr-2021  2021  1493938.0             2.858                6.1
# 196  May-2021  2021  1502642.0             2.985                5.8
# 197  Jun-2021  2021  1352285.0             3.064                5.9
#
#      Steel_Price_Index  New_Auto_Price_Index  Used_Auto_Price_Index
# 0                181.2               138.500                138.600
# ...

# %%
five_years_df=df[df["Year"]>2016]
five_years_df.head()
# Out:
#     MonthYear  Year      Sales  Price Per Gallon  Unemployment_Rate  \
# 144  Jan-2017  2017  1140841.0             2.349                4.7
# 145  Feb-2017  2017  1331716.0             2.304                4.6
# 146  Mar-2017  2017  1553142.0             2.325                4.4
# 147  Apr-2017  2017  1424793.0             2.417                4.5
# 148  May-2017  2017  1517197.0             2.391                4.4
#
#      Steel_Price_Index  New_Auto_Price_Index  Used_Auto_Price_Index
# 144              204.8               148.092                139.306
# 145              207.3               148.083                137.935
# 146              213.3               147.766                136.951
# 147              212.0               147.807                138.750
# 148              213.7               147.571                140.076

# %%
fig, ax = plt.subplots(figsize=(5,5))

x_values = five_years_df['Price Per Gallon']
y_values = five_years_df['Sales']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title('2017-2021 LR')
plt.xlabel('Price Per Gallon')
plt.ylabel('Sales (1,000,000)')
plt.grid(linestyle="-", linewidth=1, alpha=0.25)
print(f"The r-squared is: {rvalue**2}")
plt.show()

fig.savefig('Images/2017-2021 Sales vs PPG LR.png', dpi=100)
# Out:
# The r-squared is: 0.25751172565618313

# %%
# Generate a scatter plot gas price vs. auto sales
plt.scatter(mean_gas, mean_sales, color="lightskyblue", edgecolor="grey")
plt.xlabel("Average Gas Price")
plt.ylabel("Average Auto Sales (units sold)")
plt.title("Auto Sales vs Gas Prices")
plt.grid(linestyle="-", linewidth=1, alpha=0.25)

#Saves to file 
plt.savefig("Images/Gas vs Auto Sales.png")
plt.show()
print(f"The correlation coefficient between gas price and auto sales is {round(st.pearsonr(mean_gas,mean_sales)[0],2)}")

# %%
fig, ax = plt.subplots(figsize=(5,5))

x_values = df['Price Per Gallon']
y_values = df['Sales']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Price Per Gallon')
plt.ylabel('Sales (1,000,000)')
print(f"The r-squared is: {rvalue**2}")
plt.show()

fig.savefig('Images/2005-2021 Sales vs PPG LR.png', dpi=100)
# Out:
# The r-squared is: 0.0004448844826731059

# %%
fig, ax = plt.subplots(figsize=(5,5))


x_values = df['Unemployment_Rate']
y_values = df['Sales']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Unemployment_Rate')
plt.ylabel('Sales(1,000,000)')
print(f"The r-squared is: {rvalue**2}")
plt.show()

fig.savefig('Images/2005-2021 Sales vs Unemployment LR.png', dpi=100)
# Out:
# The r-squared is: 0.3786811858055365

# %%
fig, ax = plt.subplots(figsize=(5,5))

x_values = df['Steel_Price_Index']
y_values = df['Sales']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Steel_Price_Index')
plt.ylabel('Sales (1,000,000)')
print(f"The r-squared is: {rvalue**2}")
plt.show()

fig.savefig('Images/2005-2021 Sales vs SteelIDX LR.png', dpi=100)
# Out:
# The r-squared is: 0.0007519121051566269

# %%
fig, ax = plt.subplots(figsize=(2, 3))

x_values = df['New_Auto_Price_Index']
y_values = df['Sales']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('New_Auto_Price_Index')
plt.ylabel('Sales (1,000,000)')
print(f"The r-squared is: {rvalue**2}")
plt.show()

fig.savefig('Images/2005-2021 Sales vs NewAutoIDX LR.png', dpi=100)
# Out:
# The r-squared is: 0.20473944478795164

# %%
fig, ax = plt.subplots(figsize=(5, 5))

x_values = df['Used_Auto_Price_Index']
y_values = df['Sales']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Used_Auto_Price_Index')
plt.ylabel('Sales (1,000,000)')
print(f"The r-squared is: {rvalue**2}")
plt.show()

fig.savefig('Images/2005-2021 Sales vs UsedAutoIDX LR.png', dpi=100)
# Out:
# The r-squared is: 0.05536222608822764
