# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read CSV
data_df = pd.read_csv("final_data.csv")

# %%
data_df
# Out:
#     MonthYear  Year      Sales  Price Per Gallon  Unemployment_Rate  \
# 0    Jan-2005  2005  1052224.0             1.831                5.3
# 1    Feb-2005  2005  1244753.0             1.910                5.4
# 2    Mar-2005  2005  1564938.0             2.079                5.2
# 3    Apr-2005  2005  1493837.0             2.243                5.2
# 4    May-2005  2005  1488171.0             2.161                5.1
# ..        ...   ...        ...               ...                ...
# 193  Feb-2021  2021  1256529.0             2.501                6.2
# 194  Mar-2021  2021  1536038.0             2.810                6.0
# 195  Apr-2021  2021  1493938.0             2.858                6.1
# 196  May-2021  2021  1502642.0             2.985                5.8
# 197  Jun-2021  2021  1352285.0             3.064                5.9
#
#      Steel_Price_Index  New_Auto_Price_Index  Used_Auto_Price_Index
# 0                181.2               138.500                138.600
# ...

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title("Sales and Gas Price")

ax2=ax.twinx()
ax.plot(data_df["MonthYear"], data_df["Sales"], color="blue", label="Sales" )
ax2.plot(data_df["MonthYear"], data_df["Price Per Gallon"], 
                        color="green",label="Gas Price")

ax.set_xlabel("2005-2021")
ax.set_ylabel("Vehicles Sold")
ax2.set_ylabel("Gas Price")

# Create a legend for our chart
ax2.legend(loc=0)

fig.savefig('Images/2005-2021 Sales and Gas Price.png', dpi=100)

# Show the chart
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title("Sales and Unemployment Rate")

ax2=ax.twinx()
ax.plot(data_df["MonthYear"], data_df["Sales"], color="blue", label="Sales" )
ax2.plot(data_df["MonthYear"], data_df["Unemployment_Rate"], 
                        color="green",label="Unemployment Rate")

ax.set_xlabel("2005-2021")
ax.set_ylabel("Vehicles Sold")
ax2.set_ylabel("Unemployment Rate")

# Create a legend for our chart
ax2.legend(loc=0)

fig.savefig('Images/2005-2021 Sales and Unemployment Rate.png', dpi=100)

# Show the chart
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title("Sales and Unemployment Rate")

ax2=ax.twinx()
ax.plot(data_df["MonthYear"], data_df["Sales"], color="blue", label="Sales" )
ax2.plot(data_df["MonthYear"], data_df["Steel_Price_Index"], 
                        color="green",label="Steel Price")

ax.set_xlabel("2005-2021")
ax.set_ylabel("Vehicles Sold")
ax2.set_ylabel("Steel Price")

# Create a legend for our chart
ax2.legend(loc=0)

fig.savefig('Images/2005-2021 Sales and Steel Price.png', dpi=100)

# Show the chart
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title("Sales and New/Used Auto Prices")

ax2=ax.twinx()
ax.plot(data_df["MonthYear"], data_df["Sales"], color="blue", label="Sales" )
ax2.plot(data_df["MonthYear"], data_df["New_Auto_Price_Index"], 
                        color="green",label="New Auto Price")
ax2.plot(data_df["MonthYear"], data_df["Used_Auto_Price_Index"], 
                        color="orange",label="Used Auto Price")

ax.set_xlabel("2005-2021")
ax.set_ylabel("Vehicles Sold")
ax2.set_ylabel("Auto Price")

# Create a legend for our chart
ax2.legend(loc=0)

fig.savefig('Images/2005-2021 Sales and Auto Prices.png', dpi=100)

# Show the chart
plt.tight_layout()
plt.show()
